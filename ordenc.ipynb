# %%
import pandas as pd

# %%
class OrdinalEncoder():
    def __init__(self):
        self.colsEncoding=pd.DataFrame({})
    def fit_transform(self,df):
        print(df)
        for i in df:
            if i not in self.colsEncoding:
                self.colsEncoding.loc[i]={}
            n=0
            for j in df[i]:
                if j not in self.colsEncoding[i]:
                    self.colsEncoding[i][j]=n
                    n+=1
        return self.transform(df)
    def transform(self,df_in):
        df=df_in.copy()
        for i in df:
            print(i)
            for j in range(len(df[i])):
                pass
                df.loc[j,i]=self.colsEncoding[i][df[i][j]]
        return df
